# %% [markdown]
# python basic quistons

# %% [markdown]
# Q1.
# answer- python is a high level interpreted language used for many things like web development,data analytics, software development etc.
# it is popular because its easy to learn , community support large libraries.
#
#
# Q2.
# ans- an interpreter reads and executes codes line by line into machine understandable instructions .
#
# Q3.
# ans-keywords are reserved words that have a special meaning in python and cannot be assigned as variable .
#
# Q4.
# ans-no
#
# Q5.
# ans-mutability means the ability of an object to change after it is created .
#
#
# Q6.
# ans-lists are mutable because they can be changed after creating them where as in tuple once something is created it cannot be changed .
#
#
# Q7.
# ans-== compares values of two varibles
#        whereas is compares whether both are in the same memory or not ..
#
# Q8.
# ans-logical operators are used to combine multiple conditions
#
# Q9.
# ans-typecasting means chnaging one dat type into another
# ex- str to int
#
# Q10
# ans-implicit type casting means where python already knows the data that has given to it
# ex- "2" it knows its a string
# whereas in explicit type casting it is done manually using functions
# int(), str() etc
#
#
# Q11.
# ans-conditional statements helps you to code decisions based on some preconditions
# ex- if age >= 18:
#     print("adult")
#     else:
#     print("minor")
#
#
# Q12.
# ans- the if statement checks a condition if its it'll execute the block if not it will go to other cndition .
#
#
# Q13
# ans- for loop runs a fixed number of times ,usually over a sequence
#      while loop runs until a condition becomes false
#
#
# Q14.
# ans-

# %% [markdown]
# practical quistions

# %% [markdown]
# Q1. write a python program to print "hello world!"

# %%
print("hello world")
# Out:
# hello world

# %% [markdown]
# Q2. write a python program that displays your name and age ?

# %%
name = "abdul hadi"
print(name)
age = 24
print(age)
# Out:
# abdul hadi
# 24

# %% [markdown]
# Q3. write a code to print all the pre defined keywords in python using the keyword library?

# %%
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %% [markdown]
# Q4. write a program that checks if a given word is a python keyword ?

# %%
import keyword
word = input("enter a word: ")
print(keyword.iskeyword(word))
# Out:
# enter a word: else
# True

# %% [markdown]
# Q5. create a list and tuple in python, and demonstrate hoe attempting to chnage an element works differntly?

# %%
list = [1,2,3]
list[0] = 10
print(list)
# Out:
# [10, 2, 3]

# %%
tuple = 1,2,3
tuple[0] = 10
print(tuple)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2742715052.py in <cell line: 0>()
#       1 tuple = 1,2,3
# ----> 2 tuple[0] = 10
#       3 print(tuple)
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# Q6. write a function to demonstrate the behavior of mutable and immutable arguments?

# %%
list = [1,2,3]
list[0] = 10
print(list)
# Out:
# [10, 2, 3]

# %%
a = ajay,1,2,3
a[0] = 1
print(a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1380963899.py in <cell line: 0>()
# ----> 1 a = ajay,1,2,3
#       2 a[0] = 1
#       3 print(a)
#
# NameError: name 'ajay' is not defined

# %% [markdown]
# Q7. write a program that performs basic arithmatic operations on two user input numbers ?

# %%
a=2
b=5
print(a+b)
print(a-b)
print(a*b)
print(a/b)

# %% [markdown]
# Q8. write a program to demonstrate the use of logical operators ?

# %%
a = 10
b = 20

# using 'and' opreator
print(a > 5 and b > 15)
# using 'or' operator
print(a > 15 or b > 15)

# logical NOT
print(not(a > 5 and b > 15))

# %% [markdown]
# Q9. write a python program to convert user inpiut from string to integer,float and boolian types ?

# %%
a = "2"
int(a)

# %%
a = "2"
float(a)

# %%
a = ""
bool(a)

# %% [markdown]
# Q10. write code to demonstrate typecasting in list elements?

# %%
list = [ "1","2","3","4"]
# Convert each element in the list to an integer
int_list = [int(item) for item in list]
print(int_list)

# %% [markdown]
# Q11. write a program to check wheather the number is postive,negative or zero?

# %%
num = int(input("enter a number: "))
if num > 0:
  print("number is positive")
elif num < 0:
  print("number is negative")
else:
  print("number is 0")

# %% [markdown]
# Q12. write a for loop to print number from 1 to 10 ?

# %%
for i in range (1,11):
  print(i)

# %% [markdown]
# Q13.  write a program to sum of all even numbers from 1 to 50?

# %%
total_sum = 0
for i in range (1,51):
  if i % 2 == 0:
    total_sum  += i
    print(total_sum)

# %% [markdown]
# Q14. write a program to reverse a string using a while loop.

# %% [markdown]
# Q15. write a python program to calculate the factorial of a number provided by the user using a while loop.
